# %% [markdown]
# We always want our means to be zero and standard deviation to be one.
#
# FastAI v3 8 notes: https://forums.fast.ai/t/lesson-8-notes/41442/22
#
# Normalizing Inputs (C2W1L09): https://www.youtube.com/watch?v=FDCfw-YqWTE
#
# ****
#
# This is one of my random practice notebook. I try to recreate what I am learning from FastAI without refering the original notes.
#
# The reason to release this publish is to get into the habit of "To be useful: Do everything in public and for the public": https://www.youtube.com/watch?v=5UbixCFJ2DA and to build my deep learning momentum.
#
# Most/all content/ideas from this notebook are not my own but from source are links above. #NoPlagiarism

# %%
from IPython.display import Math, HTML

html = """
<iframe width="560" height="315" src="https://www.youtube.com/embed/FDCfw-YqWTE" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
"""
display(HTML(html))
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/FDCfw-YqWTE" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
import torch

# %%
x_train, x_valid = torch.randn((10000,784)), torch.randn((1000,784))

# %%
x_train.mean(), x_train.std() # mu, sigma
# Out:
# (tensor(0.0004), tensor(0.9998))

# %% [markdown]
# Since normal distribution is already mean 0 and standard deviation = 1
#
# need another dataset

# %%
from torchvision.datasets import MNIST

# %%
mnist = MNIST('', download=True)

# %%
train_data = mnist.train_data
train_data.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:53: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# torch.Size([60000, 28, 28])

# %%
perm = torch.randint(low=0, high=60000, size=(60000,))
perm
# Out:
# tensor([48529, 30135, 55383,  ...,    19,  9990, 19007])

# %%
x_train, x_valid = train_data[perm[:55000]], train_data[perm[:-5000]]

# %%
x_train.mean(), x_train.std()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-57-52592fba102f> in <module>()
# ----> 1 x_train.mean(), x_train.std()
#
# RuntimeError: Can only calculate the mean of floating types. Got Byte instead.

# %%
train_data = train_data.type(torch.float32)

# %%
x_train, x_valid = train_data[perm[:55000]], train_data[perm[:-5000]]

# %%
mean, std = x_train.mean(), x_train.std()
mean, std
# Out:
# (tensor(33.2142), tensor(78.4585))

# %%
def normalize(data, train_mean, train_std):
    return (data-train_mean)/train_std

# %%
x_train = normalize(x_train, mean, std)

# %%
x_train.mean(), x_train.std()
# Out:
# (tensor(9.6456e-05), tensor(1.))

# %%
x_valid = normalize(x_valid, mean, std)
