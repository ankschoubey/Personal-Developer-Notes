# %%
import torch

# %%
x = torch.ones(2,2)

# %%
x
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
x.shape
# Out:
# torch.Size([2, 2])

# %%
x.dtype
# Out:
# torch.float32

# %%
y = x.new_ones((2,2))

# %%
y
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
y.shape
# Out:
# torch.Size([2, 2])

# %%
y.size()
# Out:
# torch.Size([2, 2])

# %%
y.data
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
t = torch.randn(2,3, dtype=torch.double)

# %%
t
# Out:
# tensor([[-0.1101, -1.4713, -0.5243],
#         [-0.5705,  0.7466, -0.1863]], dtype=torch.float64)

# %%
torch.empty(3,2)
# Out:
# tensor([[1.1519e-35, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00]])

# %%
result = torch.empty_like(t)
torch.add(t,t, out = result)
# Out:
# tensor([[-0.2202, -2.9426, -1.0486],
#         [-1.1410,  1.4933, -0.3725]], dtype=torch.float64)

# %%
result
# Out:
# tensor([[-0.2202, -2.9426, -1.0486],
#         [-1.1410,  1.4933, -0.3725]], dtype=torch.float64)

# %%
t.view(-1,2)
# Out:
# tensor([[-0.1101, -1.4713],
#         [-0.5243, -0.5705],
#         [ 0.7466, -0.1863]], dtype=torch.float64)

# %%
t
# Out:
# tensor([[-0.1101, -1.4713, -0.5243],
#         [-0.5705,  0.7466, -0.1863]], dtype=torch.float64)

# %%
t.mean().item()
# Out:
# -0.3526406547273531

# %%
t_num = t.numpy()

# %%
t_num = t_num*2
t_num
# Out:
# array([[-0.44038389, -5.8852472 , -2.09718127],
#        [-2.28204077,  2.98656565, -0.74508823]])

# %%
t
# Out:
# tensor([[-0.1101, -1.4713, -0.5243],
#         [-0.5705,  0.7466, -0.1863]], dtype=torch.float64)

# %%
t_num[0,0] = 200

# %%
t_num
# Out:
# array([[ 2.00000000e+02, -1.47131180e+00, -5.24295318e-01],
#        [-5.70510193e-01,  7.46641413e-01, -1.86272057e-01]])

# %%
t
# Out:
# tensor([[ 2.0000e+02, -1.4713e+00, -5.2430e-01],
#         [-5.7051e-01,  7.4664e-01, -1.8627e-01]], dtype=torch.float64)

# %%
ten = torch.tensor([3,2,4])

# %%
import numpy as np

# %%
np_ten = np.array([1,2,3])

# %%
np_ten
# Out:
# array([1, 2, 3])

# %%
torch.from_numpy(np_ten)
# Out:
# tensor([1, 2, 3])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
x
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
x.to(device)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], device='cuda:0')

# %%
x
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
h = torch.tensor([1.], requires_grad=True)

# %%
h
# Out:
# tensor([1.], requires_grad=True)

# %%
y=h+20

# %%
y
# Out:
# tensor([21.], grad_fn=<AddBackward0>)

# %%
y.grad_fn

# %%
y.grad

# %%
y.backward()

# %%
h
# Out:
# tensor([0.7000], grad_fn=<SubBackward0>)

# %%
while y.item()!=0 and h.grad:
    y = h+20
    y.backward()
    h= h -0.1*h.grad
    print(f'y={y} h={h}')
# Out:
# y=tensor([21.], grad_fn=<AddBackward0>) h=tensor([0.8000], grad_fn=<SubBackward0>)

# %%
y = h+20
y.backward()
h= h -0.1*h.grad
print(f'y={y} h={h}')
h.grad.data.zero_()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-42cef9fd0dc3> in <module>()
#       1 y = h+20
#       2 y.backward()
# ----> 3 h= h -0.1*h.grad
#       4 print(f'y={y} h={h}')
#       5 h.grad.data.zero_()
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
y = h+20
y
# Out:
# tensor([20.8000], grad_fn=<AddBackward0>)

# %%
y.backward()
h.grad.data.zero_()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-a6062583d107> in <module>()
#       1 y.backward()
# ----> 2 h.grad.data.zero_()
#
# AttributeError: 'NoneType' object has no attribute 'data'

# %%
y.data.norm()
# Out:
# tensor(20.8000)

# %%
with torch.no_grad():
    print(h.requires_grad)
# Out:
# True
