# %%
from IPython.display import display, HTML, Javascript

# %%
from IPython.display import IFrame

#IFrame(src='https://www1.nseindia.com/live_market/dynaContent/live_watch/option_chain/optionKeys.jsp', width=700, height=600)
