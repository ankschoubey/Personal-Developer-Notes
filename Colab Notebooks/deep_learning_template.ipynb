# %% [markdown]
# # Useful templates and constants

# %%
#@title  { display-mode: "form" }
from google.colab import drive
from pprint import pprint
from tqdm import tqdm

#@markdown ### Description

project_name = 'Deep Learning Template' #@param {type:"string"}
#@markdown 
source_url = "" #@param {type:"string"}

project_type = "Getting Started" #@param ["Getting Started", "Playground", "Competition", "Research"]
significance = "" #@param {type:"string"}

#@markdown ### DevOps

github_url = "" #@param {type:"string"}
#TODO: GITHUB Integration and commit while saving and notebook export while saving
#@markdown ### Planning

importance = 4 #@param {type:"slider", min:1, max:10, step:1}

deadline_if_any = "2019-10-11" #@param {type:"date"}
interactive_dataframe = True #@param {type:"boolean"}

if interactive_dataframe:
    # %load_ext google.colab.data_table
else:
    # %unload_ext google.colab.data_table

drive.mount('/content/drive')
path = Path('/content/drive/My Drive/Colab Notebooks') / project_name
if not path.exists(): path.mkdir()

pprint(path.ls())

# %%
#@title Give me a name {display-mode: "form"}

# This code will be hidden when the notebook is loaded.

# %%
data.cars()

# %%
import google

# %%
type(a)

# %%
def get_save_name(stage,lr,epochs): return 'stage-{stage}-lr-{lr}-epochs-{epochs}'

# %% [markdown]
# # Importing the libraries

# %%
from fastai import *
from fastai.vision import *
from fastai.text import *

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
"""Tags"""

#code-done: When you perfectle understand what a cell does
#math-done: When you perfectly understand what equation does
#export

# %% [markdown]
# # Importing the dataset

# %%
data = None

# %%
data.show_batch()

# %%
get_save_name(stage,lr,epochs)

# %% [markdown]
# # Model Creation

# %%
learn =

# %% [markdown]
# # Fit Model

# %% [markdown]
# ## Freezed

# %%
learn.lr_find()
learn.recorder.plot()

# %%
stage = 1
lr = 0.2
epochs = 5 
#learn.fit_one_cycle(epochs, lr)
#learn.save(export_name.format(stage,lr,epochs))
export_name.format(stage,lr,epochs)

# %% [markdown]
# ## Unfreezed

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()

# %%
lr = 
epochs = 
learn.fit_one_cycle(epochs, lr)

# %% [markdown]
# # Interpretation

# %%
classification

# %% [markdown]
# # Predict test set result and output file

# %%
# !git clone
